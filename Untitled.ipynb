# %%
print("hello there")
# Out:
# hello there

# %%
print("hi there")
# Out:
# hi there

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
data=[['radha',21],['kanha',23],['arjun',22]]
df=pd.DataFrame(data,columns=['name','age'])
print(df)
# Out:
#     name  age
# 0  radha   21
# 1  kanha   23
# 2  arjun   22

# %%
import pandas as pd

# Initialize data to lists.
data = [{'a': 1, 'b': 2, 'c': 3},
        {'a': 10, 'b': 20, 'c': 30}]

# Creates DataFrame.
df = pd.DataFrame(data)

print(df)
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30
